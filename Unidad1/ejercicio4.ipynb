# %% [markdown]
# <a href="https://colab.research.google.com/github/federicnacio/probabilidad/blob/main/Unidad1/ejercicio4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Estadística descriptiva

# %% [markdown]
# Practica 4
#
# tablas de frecuencias

# %%
import random
Edades = []
for I in range(100):
 número_aleatorio = random.randint(18, 70)
 Edades.append(número_aleatorio)
print(Edades)
# Out:
# [29, 35, 69, 47, 30, 23, 64, 32, 22, 35, 69, 24, 35, 19, 25, 60, 68, 47, 29, 39, 46, 37, 67, 45, 25, 45, 60, 60, 51, 49, 61, 20, 59, 38, 43, 43, 43, 22, 61, 44, 26, 42, 70, 49, 27, 20, 18, 30, 34, 32, 41, 69, 25, 63, 41, 45, 65, 56, 37, 51, 68, 18, 55, 51, 18, 18, 27, 28, 55, 60, 25, 69, 44, 43, 46, 51, 37, 20, 38, 50, 67, 47, 61, 28, 70, 39, 47, 61, 33, 69, 66, 61, 19, 20, 39, 43, 63, 48, 29, 45]

# %%
import pandas as pd

# %%
Df = pd.DataFrame(Edades, columns=['Edad'])
Df.head()
# Out:
#    Edad
# 0    29
# 1    35
# 2    69
# 3    47
# 4    30

# %%
tabla_frecuencias = Df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

print("Tablas de distribución de frecuencias:")
tabla_frecuencias
# Out:
# Tablas de distribución de frecuencias:
#     Edad  Frecuencia
# 4     18           4
# 28    19           2
# 5     20           4
# 26    22           2
# 38    23           1
# 41    24           1
# 8     25           4
# 37    26           1
# 18    27           2
# 15    28           2
# 13    29           3
# 17    30           2
# 24    32           2
# 32    33           1
# 36    34           1
# 11    35           3
# 12    37           3
# 23    38           2
# 10    39           3
# 16    41           2
# 35    42           1
# 2     43           5
# 22    44           2
# 7     45           4
# 20    46           2
# 3     47           4
# 42    48           1
# 25    49           2
# 31    50           1
# 6     51           4
# 21    55           2
# 34    56           1
# 39    59           1
# 9     60           4
# 0     61           5
# 29    63           2
# 40    64           1
# 30    65           1
# 33    66           1
# 27    67           2
# 14    68           2
# 1     69           5
# 19    70           2

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia']/100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 4     18           4           0.04
# 28    19           2           0.02
# 5     20           4           0.04
# 26    22           2           0.02
# 38    23           1           0.01
# 41    24           1           0.01
# 8     25           4           0.04
# 37    26           1           0.01
# 18    27           2           0.02
# 15    28           2           0.02
# 13    29           3           0.03
# 17    30           2           0.02
# 24    32           2           0.02
# 32    33           1           0.01
# 36    34           1           0.01
# 11    35           3           0.03
# 12    37           3           0.03
# 23    38           2           0.02
# 10    39           3           0.03
# 16    41           2           0.02
# 35    42           1           0.01
# 2     43           5           0.05
# 22    44           2           0.02
# 7     45           4           0.04
# 20    46           2           0.02
# 3     47           4           0.04
# 42    48           1           0.01
# 25    49           2           0.02
# 31    50           1           0.01
# 6     51           4           0.04
# 21    55           2           0.02
# 34    56           1           0.01
# 39    59           1           0.01
# 9     60           4           0.04
# 0     61           5           0.05
# 29    63           2           0.02
# 40    64           1           0.01
# 30    65           1           0.01
# 33    66           1           0.01
# 27    67           2           0.02
# 14    68           2           0.02
# 1     69           5           0.05
# 19    70           2           0.02

# %%
tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia']/100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 4     18           4           0.04              4.0
# 28    19           2           0.02              2.0
# 5     20           4           0.04              4.0
# 26    22           2           0.02              2.0
# 38    23           1           0.01              1.0
# 41    24           1           0.01              1.0
# 8     25           4           0.04              4.0
# 37    26           1           0.01              1.0
# 18    27           2           0.02              2.0
# 15    28           2           0.02              2.0
# 13    29           3           0.03              3.0
# 17    30           2           0.02              2.0
# 24    32           2           0.02              2.0
# 32    33           1           0.01              1.0
# 36    34           1           0.01              1.0
# 11    35           3           0.03              3.0
# 12    37           3           0.03              3.0
# 23    38           2           0.02              2.0
# 10    39           3           0.03              3.0
# 16    41           2           0.02              2.0
# 35    42           1           0.01              1.0
# 2     43           5           0.05              5.0
# 22    44           2           0.02              2.0
# 7     45           4           0.04              4.0
# 20    46           2           0.02              2.0
# 3     47           4           0.04              4.0
# 42    48           1           0.01              1.0
# 25    49           2           0.02              2.0
# 31    50           1           0.01              1.0
# 6     51           4           0.04              4.0
# 21    55           2           0.02              2.0
# 34    56           1           0.01              1.0
# 39    59           1           0.01              1.0
# 9     60           4           0.04              4.0
# 0     61           5           0.05              5.0
# 29    63           2           0.02              2.0
# 40    64           1           0.01              1.0
# 30    65           1           0.01              1.0
# 33    66           1           0.01              1.0
# 27    67           2           0.02              2.0
# 14    68           2           0.02              2.0
# 1     69           5           0.05              5.0
# 19    70           2           0.02              2.0

# %%
tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 4     18           4           0.04              4.0               4
# 28    19           2           0.02              2.0               6
# 5     20           4           0.04              4.0              10
# 26    22           2           0.02              2.0              12
# 38    23           1           0.01              1.0              13
# 41    24           1           0.01              1.0              14
# 8     25           4           0.04              4.0              18
# 37    26           1           0.01              1.0              19
# 18    27           2           0.02              2.0              21
# 15    28           2           0.02              2.0              23
# 13    29           3           0.03              3.0              26
# 17    30           2           0.02              2.0              28
# 24    32           2           0.02              2.0              30
# 32    33           1           0.01              1.0              31
# 36    34           1           0.01              1.0              32
# 11    35           3           0.03              3.0              35
# 12    37           3           0.03              3.0              38
# 23    38           2           0.02              2.0              40
# 10    39           3           0.03              3.0              43
# 16    41           2           0.02              2.0              45
# 35    42           1           0.01              1.0              46
# 2     43           5           0.05              5.0              51
# 22    44           2           0.02              2.0              53
# 7     45           4           0.04              4.0              57
# 20    46           2           0.02              2.0              59
# 3     47           4           0.04              4.0              63
# 42    48           1           0.01              1.0              64
# 25    49           2           0.02              2.0              66
# 31    50           1           0.01              1.0              67
# 6     51           4           0.04              4.0              71
# 21    55           2           0.02              2.0              73
# 34    56           1           0.01              1.0              74
# 39    59           1           0.01              1.0              75
# 9     60           4           0.04              4.0              79
# 0     61           5           0.05              5.0              84
# 29    63           2           0.02              2.0              86
# 40    64           1           0.01              1.0              87
# 30    65           1           0.01              1.0              88
# 33    66           1           0.01              1.0              89
# 27    67           2           0.02              2.0              91
# 14    68           2           0.02              2.0              93
# 1     69           5           0.05              5.0              98
# 19    70           2           0.02              2.0             100

# %% [markdown]
# Regla de strugles
#
# c=1+log(N)
# N=tamaño de muestra

# %%
import math

# %%
print (Edades)
# Out:
# [29, 35, 69, 47, 30, 23, 64, 32, 22, 35, 69, 24, 35, 19, 25, 60, 68, 47, 29, 39, 46, 37, 67, 45, 25, 45, 60, 60, 51, 49, 61, 20, 59, 38, 43, 43, 43, 22, 61, 44, 26, 42, 70, 49, 27, 20, 18, 30, 34, 32, 41, 69, 25, 63, 41, 45, 65, 56, 37, 51, 68, 18, 55, 51, 18, 18, 27, 28, 55, 60, 25, 69, 44, 43, 46, 51, 37, 20, 38, 50, 67, 47, 61, 28, 70, 39, 47, 61, 33, 69, 66, 61, 19, 20, 39, 43, 63, 48, 29, 45]

# %%
Df = pd.DataFrame({'Edad': Edades})
Df
# Out:
#     Edad
# 0     29
# 1     35
# 2     69
# 3     47
# 4     30
# ..   ...
# 95    43
# 96    63
# 97    48
# 98    29
# 99    45
#
# [100 rows x 1 columns]

# %%
n = len(Edades)
K = int(1+math.log2(n))
print("valor de n :", n , "\nNumero de intervalos :", K)
# Out:
# valor de n : 100
# Numero de intervalos : 7

# %%
tabla_frecuencia = pd.cut(Df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (40.286, 47.714]    20
# 1  (17.947, 25.429]    18
# 2    (62.571, 70.0]    16
# 3  (32.857, 40.286]    13
# 4  (25.429, 32.857]    12
# 5  (55.143, 62.571]    11
# 6  (47.714, 55.143]    10

# %%
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 1  (17.947, 25.429]    18
# 4  (25.429, 32.857]    12
# 3  (32.857, 40.286]    13
# 0  (40.286, 47.714]    20
# 6  (47.714, 55.143]    10
# 5  (55.143, 62.571]    11
# 2    (62.571, 70.0]    16

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec']/n
tabla_frecuencia['FrecPorc'] = tabla_frecuencia['Frec']/n*100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['FrecPorc Ac'] = tabla_frecuencia['FrecPorc'].cumsum()
tabla_frecuencia
# Out:
#               Clase  Frec  Frec Rel  FrecPorc  Frec Ac  Frec Rel Ac  \
# 1  (17.947, 25.429]    18      0.18      18.0       18         0.18
# 4  (25.429, 32.857]    12      0.12      12.0       30         0.30
# 3  (32.857, 40.286]    13      0.13      13.0       43         0.43
# 0  (40.286, 47.714]    20      0.20      20.0       63         0.63
# 6  (47.714, 55.143]    10      0.10      10.0       73         0.73
# 5  (55.143, 62.571]    11      0.11      11.0       84         0.84
# 2    (62.571, 70.0]    16      0.16      16.0      100         1.00
#
#    FrecPorc Ac
# 1         18.0
# 4         30.0
# 3         43.0
# 0         63.0
# 6         73.0
# 5         84.0
# 2        100.0

# %%
import matplotlib.pyplot as plt
plt.hist(Edades, alpha = 0.5, bins=20)
plt.title("histograma de edades basada en la función de matplotlib con valores estándar")
# Out:
# Text(0.5, 1.0, 'histograma de edades basada en la función de matplotlib con valores estándar')

# %%
plt.hist(Df['Edad'], bins=K, alpha=0.5)
plt.title('histograma edades basado en la regla de sturges')
plt.xlabel('edades')
plt.ylabel('frecuencia')
# Out:
# Text(0, 0.5, 'frecuencia')

# %% [markdown]
# Practica 5
#
# Diagramas de cajas y bigotes

# %%
import random
Edades2 = []
for I in range(100):
 número_aleatorio = random.randint(18, 70)
 Edades2.append(número_aleatorio)
print(Edades2)
# Out:
# [32, 24, 49, 47, 68, 45, 30, 34, 29, 23, 51, 69, 46, 36, 69, 63, 34, 63, 60, 58, 22, 41, 42, 28, 20, 58, 24, 36, 66, 29, 23, 21, 42, 29, 46, 56, 63, 34, 23, 54, 36, 64, 58, 67, 67, 61, 18, 26, 65, 68, 37, 44, 44, 65, 27, 61, 25, 28, 54, 23, 35, 27, 39, 43, 43, 24, 22, 47, 28, 26, 24, 63, 60, 62, 25, 70, 20, 44, 36, 63, 47, 66, 48, 28, 56, 20, 63, 37, 41, 37, 34, 61, 61, 39, 30, 63, 28, 65, 26, 69]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(9,4))
bplot1 = ax1.boxplot(Edades, vert=True, patch_artist=True)
ax1.set_title('edades encuesta 1')
bplot2 = ax2.boxplot(Edades2, vert=True,patch_artist=True)
ax2.set_title('edades encuesta 2')
plt.show()

# %%
Edades2.append(130)

# %%
fig, (ax1, ax2) = plt.subplots (nrows=1, ncols=2, figsize=(9, 4))
bplot1 = ax1.boxplot(Edades, vert=True, patch_artist=True)
ax1.set_title('edades encuesta 1')
bplot2 = ax2.boxplot(Edades2, vert=True, patch_artist=True)
ax2.set_title('edades encuesta 2')
plt.show()
